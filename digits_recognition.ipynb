# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, Y_train), (X_test, Y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 7s 1us/step

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
len(X_train)
# Out:
# 60000

# %%
len(X_test)
# Out:
# 10000

# %%
plt.matshow(X_train[0])

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_train_flattened.shape
# Out:
# (60000, 784)

# %%
X_test_flattened = X_test.reshape(len(X_test), 28*28)
X_test_flattened.shape
# Out:
# (10000, 784)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='sigmoid')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train_flattened, Y_train, epochs=5)
# Out:
# Epoch 1/5
#   17/1875 [..............................] - ETA: 11s - loss: 2.1099 - accuracy: 0.3309
# 2023-03-26 20:53:54.305115: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4674 - accuracy: 0.8777
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3037 - accuracy: 0.9152
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2832 - accuracy: 0.9205
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2732 - accuracy: 0.9234
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2666 - accuracy: 0.9251

# %%
model.evaluate(X_test_flattened, Y_test)
# Out:
#  32/313 [==>...........................] - ETA: 1s - loss: 0.2769 - accuracy: 0.9160
# 2023-03-26 20:55:18.112100: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2681 - accuracy: 0.9246
# [0.26806992292404175, 0.9246000647544861]

# %%
plt.matshow(X_test[10])

# %%
y_predicted = model.predict(X_test_flattened)
# Out:
#  73/313 [=====>........................] - ETA: 0s
# 2023-03-26 20:57:07.032347: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step

# %%
y_predicted[10]
# Out:
# array([9.9858904e-01, 1.3343596e-07, 4.4380587e-01, 1.1110510e-01,
#        2.1837594e-04, 8.3579320e-01, 2.9447367e-02, 2.3397040e-05,
#        7.4469411e-01, 2.4106355e-04], dtype=float32)

# %%
np.argmax(y_predicted[10])
# Out:
# 0

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]
y_predicted_labels
# Out:
# [7,
#  2,
#  1,
#  0,
#  4,
#  1,
#  4,
#  9,
#  6,
#  9,
#  0,
#  6,
#  9,
#  0,
#  1,
#  5,
#  9,
#  7,
#  3,
#  4,
#  9,
#  6,
#  6,
#  5,
#  4,
#  0,
#  7,
#  4,
#  0,
#  1,
#  3,
#  1,
#  3,
#  0,
#  7,
#  2,
#  7,
#  1,
#  2,
#  1,
#  1,
#  7,
#  4,
#  2,
#  3,
#  5,
#  1,
#  2,
#  4,
#  4,
#  6,
#  3,
#  5,
#  5,
#  6,
#  0,
#  4,
#  1,
#  9,
#  5,
#  7,
#  8,
#  9,
#  2,
#  7,
#  4,
#  2,
#  4,
#  3,
#  0,
#  7,
#  0,
#  2,
#  9,
#  1,
#  7,
#  3,
#  2,
#  9,
#  7,
#  7,
#  6,
#  2,
#  7,
#  8,
#  4,
#  7,
#  3,
#  6,
#  1,
#  3,
#  6,
#  9,
#  3,
#  1,
#  4,
#  1,
#  7,
#  6,
#  9,
#  6,
#  0,
#  5,
#  4,
#  9,
#  9,
#  2,
#  1,
#  9,
#  4,
#  8,
#  7,
#  3,
#  9,
#  7,
#  4,
#  4,
#  4,
#  9,
#  2,
#  5,
#  4,
#  7,
#  6,
#  7,
#  9,
#  0,
#  5,
#  8,
#  5,
#  6,
#  6,
#  5,
#  7,
#  8,
#  1,
#  0,
#  1,
#  6,
#  4,
#  6,
#  7,
#  3,
#  1,
#  7,
#  1,
#  8,
#  2,
#  0,
#  9,
#  9,
#  9,
#  5,
#  5,
#  1,
#  5,
#  6,
#  0,
#  3,
#  4,
#  4,
#  6,
#  5,
#  4,
#  6,
#  5,
#  4,
#  5,
#  1,
#  4,
#  4,
#  7,
#  2,
#  3,
#  2,
#  7,
#  1,
#  8,
#  1,
#  8,
#  1,
#  8,
#  5,
#  0,
#  8,
#  9,
#  2,
#  5,
#  0,
#  1,
#  1,
#  1,
#  0,
#  3,
#  0,
#  8,
#  1,
#  6,
#  4,
#  2,
#  3,
#  6,
#  1,
#  1,
#  1,
#  3,
#  9,
#  5,
#  2,
#  9,
#  4,
#  7,
#  9,
#  3,
#  9,
#  0,
#  3,
#  5,
#  5,
#  5,
#  7,
#  2,
#  2,
#  7,
#  1,
#  2,
#  8,
#  4,
#  1,
#  7,
#  3,
#  3,
#  8,
#  7,
#  7,
#  9,
#  2,
#  2,
#  4,
#  1,
#  5,
#  8,
#  8,
#  7,
#  2,
#  5,
#  0,
#  2,
#  4,
#  2,
#  4,
#  1,
#  9,
#  5,
#  7,
#  7,
#  2,
#  8,
#  2,
#  0,
#  8,
#  5,
#  7,
#  7,
#  9,
#  1,
#  8,
#  1,
#  8,
#  0,
#  3,
#  0,
#  1,
#  9,
#  9,
#  4,
#  1,
#  8,
#  2,
#  1,
#  2,
#  9,
#  7,
#  5,
#  9,
#  2,
#  6,
#  4,
#  1,
#  5,
#  4,
#  2,
#  9,
#  2,
#  0,
#  4,
#  0,
#  0,
#  2,
#  8,
#  6,
#  7,
#  1,
#  2,
#  4,
#  0,
#  2,
#  9,
#  4,
#  3,
#  3,
#  0,
#  0,
#  3,
#  1,
#  9,
#  6,
#  5,
#  3,
#  5,
#  7,
#  7,
#  9,
#  3,
#  0,
#  4,
#  2,
#  0,
#  7,
#  1,
#  1,
#  2,
#  1,
#  5,
#  3,
#  3,
#  9,
#  7,
#  8,
#  6,
#  3,
#  6,
#  1,
#  3,
#  8,
#  1,
#  0,
#  5,
#  1,
#  3,
#  1,
#  5,
#  0,
#  6,
#  1,
#  8,
#  5,
#  1,
#  7,
#  4,
#  4,
#  6,
#  7,
#  2,
#  5,
#  0,
#  6,
#  5,
#  6,
#  3,
#  7,
#  2,
#  0,
#  8,
#  8,
#  5,
#  4,
#  1,
#  1,
#  4,
#  0,
#  7,
#  3,
#  7,
#  6,
#  1,
#  6,
#  2,
#  1,
#  9,
#  2,
#  8,
#  6,
#  1,
#  9,
#  5,
#  2,
#  5,
#  4,
#  4,
#  2,
#  8,
#  3,
#  8,
#  2,
#  4,
#  8,
#  0,
#  3,
#  1,
#  7,
#  7,
#  3,
#  7,
#  9,
#  7,
#  1,
#  9,
#  2,
#  1,
#  4,
#  2,
#  9,
#  2,
#  0,
#  4,
#  9,
#  1,
#  4,
#  8,
#  1,
#  8,
#  4,
#  5,
#  9,
#  7,
#  8,
#  3,
#  7,
#  6,
#  0,
#  0,
#  3,
#  0,
#  8,
#  0,
#  6,
#  4,
#  8,
#  3,
#  3,
#  3,
#  2,
#  3,
#  9,
#  1,
#  2,
#  6,
#  8,
#  0,
#  5,
#  6,
#  6,
#  6,
#  3,
#  8,
#  8,
#  2,
#  9,
#  8,
#  8,
#  9,
#  6,
#  1,
#  8,
#  4,
#  1,
#  2,
#  8,
#  3,
#  1,
#  9,
#  7,
#  5,
#  4,
#  0,
#  8,
#  9,
#  9,
#  1,
#  0,
#  5,
#  2,
#  3,
#  7,
#  8,
#  9,
#  4,
#  0,
#  6,
#  3,
#  9,
#  3,
#  2,
#  1,
#  3,
#  1,
#  5,
#  6,
#  5,
#  7,
#  8,
#  2,
#  2,
#  6,
#  3,
#  2,
#  6,
#  5,
#  4,
#  8,
#  9,
#  7,
#  1,
#  3,
#  0,
#  3,
#  8,
#  3,
#  1,
#  4,
#  6,
#  4,
#  4,
#  6,
#  4,
#  1,
#  1,
#  8,
#  2,
#  5,
#  4,
#  8,
#  3,
#  4,
#  0,
#  0,
#  2,
#  3,
#  2,
#  7,
#  1,
#  0,
#  8,
#  7,
#  4,
#  4,
#  7,
#  9,
#  6,
#  9,
#  0,
#  9,
#  8,
#  0,
#  9,
#  6,
#  0,
#  6,
#  5,
#  5,
#  4,
#  8,
#  3,
#  3,
#  9,
#  3,
#  3,
#  2,
#  7,
#  8,
#  0,
#  2,
#  8,
#  1,
#  7,
#  0,
#  6,
#  5,
#  4,
#  3,
#  3,
#  0,
#  9,
#  6,
#  3,
#  8,
#  0,
#  9,
#  9,
#  6,
#  8,
#  6,
#  8,
#  5,
#  7,
#  8,
#  6,
#  0,
#  2,
#  4,
#  0,
#  2,
#  8,
#  3,
#  1,
#  9,
#  7,
#  5,
#  8,
#  0,
#  8,
#  4,
#  6,
#  2,
#  6,
#  7,
#  4,
#  9,
#  6,
#  9,
#  8,
#  2,
#  2,
#  9,
#  2,
#  7,
#  3,
#  5,
#  9,
#  1,
#  8,
#  0,
#  2,
#  0,
#  5,
#  2,
#  1,
#  3,
#  7,
#  6,
#  7,
#  1,
#  2,
#  5,
#  8,
#  0,
#  3,
#  7,
#  8,
#  4,
#  0,
#  9,
#  1,
#  8,
#  6,
#  7,
#  7,
#  4,
#  3,
#  4,
#  9,
#  1,
#  9,
#  5,
#  1,
#  7,
#  3,
#  9,
#  7,
#  6,
#  9,
#  1,
#  3,
#  3,
#  8,
#  3,
#  3,
#  6,
#  7,
#  2,
#  4,
#  5,
#  8,
#  5,
#  1,
#  1,
#  4,
#  4,
#  3,
#  1,
#  0,
#  7,
#  7,
#  0,
#  7,
#  9,
#  9,
#  4,
#  8,
#  5,
#  5,
#  4,
#  0,
#  8,
#  2,
#  1,
#  6,
#  8,
#  4,
#  2,
#  0,
#  4,
#  0,
#  6,
#  1,
#  7,
#  3,
#  8,
#  6,
#  7,
#  2,
#  6,
#  9,
#  3,
#  1,
#  4,
#  6,
#  8,
#  5,
#  9,
#  8,
#  0,
#  6,
#  2,
#  1,
#  7,
#  3,
#  4,
#  1,
#  0,
#  5,
#  4,
#  3,
#  1,
#  1,
#  7,
#  4,
#  9,
#  9,
#  9,
#  8,
#  4,
#  0,
#  2,
#  4,
#  5,
#  1,
#  1,
#  6,
#  4,
#  7,
#  1,
#  9,
#  4,
#  2,
#  4,
#  1,
#  5,
#  5,
#  3,
#  8,
#  3,
#  1,
#  4,
#  5,
#  6,
#  8,
#  9,
#  4,
#  1,
#  9,
#  3,
#  8,
#  0,
#  3,
#  2,
#  5,
#  1,
#  2,
#  8,
#  3,
#  4,
#  4,
#  0,
#  8,
#  8,
#  3,
#  3,
#  1,
#  7,
#  3,
#  5,
#  9,
#  6,
#  3,
#  2,
#  6,
#  1,
#  3,
#  6,
#  0,
#  7,
#  2,
#  1,
#  7,
#  1,
#  4,
#  2,
#  8,
#  2,
#  1,
#  7,
#  9,
#  6,
#  1,
#  1,
#  2,
#  4,
#  3,
#  1,
#  7,
#  7,
#  4,
#  7,
#  0,
#  7,
#  3,
#  1,
#  3,
#  1,
#  0,
#  7,
#  7,
#  0,
#  3,
#  5,
#  3,
#  2,
#  7,
#  6,
#  6,
#  9,
#  2,
#  8,
#  3,
#  5,
#  2,
#  2,
#  5,
#  6,
#  0,
#  8,
#  2,
#  9,
#  2,
#  8,
#  2,
#  8,
#  8,
#  7,
#  9,
#  9,
#  3,
#  0,
#  6,
#  6,
#  3,
#  2,
#  1,
#  3,
#  2,
#  2,
#  9,
#  3,
#  0,
#  0,
#  5,
#  2,
#  8,
#  1,
#  4,
#  4,
#  6,
#  0,
#  2,
#  9,
#  1,
#  4,
#  7,
#  4,
#  7,
#  3,
#  9,
#  8,
#  8,
#  4,
#  7,
#  1,
#  2,
#  1,
#  2,
#  2,
#  3,
#  7,
#  3,
#  2,
#  3,
#  9,
#  1,
#  7,
#  4,
#  0,
#  3,
#  5,
#  5,
#  8,
#  6,
#  5,
#  0,
#  6,
#  7,
#  6,
#  6,
#  3,
#  2,
#  7,
#  9,
#  1,
#  1,
#  2,
#  4,
#  6,
#  4,
#  9,
#  5,
#  6,
#  3,
#  3,
#  4,
#  7,
#  8,
#  9,
#  1,
#  1,
#  0,
#  9,
#  1,
#  4,
#  4,
#  5,
#  4,
#  0,
#  6,
#  2,
#  3,
#  3,
#  1,
#  5,
#  1,
#  2,
#  0,
#  3,
#  8,
#  1,
#  2,
#  6,
#  7,
#  1,
#  6,
#  2,
#  3,
#  9,
#  0,
#  1,
#  2,
#  2,
#  0,
#  8,
#  7,
#  ...]

# %%
confusion_matrix = tf.math.confusion_matrix(labels=Y_test, predictions=y_predicted_labels)
confusion_matrix
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 964,    0,    0,    2,    0,    4,    5,    2,    3,    0],
#        [   0, 1113,    3,    2,    0,    1,    4,    2,   10,    0],
#        [   7,    9,  916,   19,   10,    4,   12,   10,   42,    3],
#        [   4,    0,   15,  927,    1,   21,    1,   12,   24,    5],
#        [   2,    1,    4,    2,  920,    0,    9,    4,   11,   29],
#        [   9,    3,    2,   41,   12,  760,   16,    6,   38,    5],
#        [  13,    3,    5,    2,    7,   12,  912,    2,    2,    0],
#        [   1,    6,   21,    9,    6,    0,    0,  954,    5,   26],
#        [   5,    7,    6,   25,    9,   22,    9,   11,  875,    5],
#        [  10,    6,    1,   12,   32,    7,    0,   26,   10,  905]],
#       dtype=int32)>

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(confusion_matrix, annot=True, fmt='d')
plt.xlabel('Truth')
plt.ylabel('Predicted')
# Out:
# Text(95.72222222222221, 0.5, 'Predicted')

# %%
model = keras.Sequential([
    keras.layers.Dense(100, input_shape=(784,), activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train_flattened, Y_train, epochs=5)
# Out:
# Epoch 1/5
# 2023-03-26 21:06:55.793858: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2760 - accuracy: 0.9214
# Epoch 2/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1258 - accuracy: 0.9629
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0870 - accuracy: 0.9741
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0659 - accuracy: 0.9800
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0511 - accuracy: 0.9841
